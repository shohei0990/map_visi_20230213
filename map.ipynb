# %%
import requests
import json
import pandas as pd 
from urllib.parse import urlencode

# %%
data = pd.read_csv('map_info.csv')
data.head(3)
# Out:
#    Unnamed: 0                    名称    カテゴリー        アドレス                 アクセス  \
# 0           0  東急目黒線 武蔵小山駅 6階建 築15年  賃貸マンション  東京都品川区小山台１     東急池上線/戸越銀座駅 歩18分
# 1           1    ＪＲ山手線 大崎駅 6階建 築20年  賃貸マンション   東京都品川区大崎１    ＪＲ京浜東北線/大井町駅 歩19分
# 2           2           レオパレスオブリカーサ  賃貸マンション  東京都品川区南品川３  りんかい線/品川シーサイド駅 歩13分
#
#     築年数   構造  階数      家賃     管理費 敷金     礼金 間取り       面積  \
# 0  築15年  6階建  4階   8.5万円  15000円  -      -  1K  21.66m2
# 1  築20年  6階建  4階   8.4万円  10000円  -  8.4万円  1K  21.57m2
# 2  築14年  3階建  3階  10.2万円   5500円  -      -  1K  19.14m2
#
#                                                  URL          経度         緯度
# 0  https://suumo.jp/chintai/jnc_000078958101/?bc=...  139.706985  35.623516
# 1  https://suumo.jp/chintai/jnc_000045421504/?bc=...  139.729462  35.620152
# 2  https://suumo.jp/chintai/jnc_000078846769/?bc=...  139.743912  35.608734

# %%
data['緯度'][1]
# Out:
# 35.620152

# %%
#パラメータリスト
api_key = 'AIzaSyAdFUui2C-RKcw48ApjPQJtBR_AAxIoWg4'
lat, lng = data['緯度'][1], data['経度'][1]
radius = 500
keyword = "コンビニ"
language = 'ja'
minprice = 0
maxprice = 4
#fields = ['opennow']
#rankby = 'prominence'
#type = 'cafe'

# %%
#エンドポイントURL
places_endpoint = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#パラメータ
params = {
    "key": api_key,
    "location": f"{lat},{lng}",
    "radius": radius,
    "keyword": keyword,
    "language":language,
    #"minprice": minprice,
    #"maxprice": maxprice,
    # "fields": fields,
    # "rankby": rankby,
    # "type": type
}

# %%
#URLエンコード
params_encoded = urlencode(params)
#リクエストURL生成
places_url = f"{places_endpoint}?{params_encoded}"

#結果取得
r = requests.get(places_url)
data = r.json()
#結果出力
print(json.dumps(data, indent=2))
# Out:
# {
#   "html_attributions": [],
#   "next_page_token": "AfLeUgNzduqquGcKPoHxLigSnvnOqsCd19ylmmPyJ8-nt7aq2ulyuAW8dZfhXCboTVVOazNzWWqkH32fobiguhWogqzGpU98Dl8V9HRIxEs6HXZ0uSIQpLENXBPz4HHi9SAHU-tCX8e7I43O1nAb2HPNJVpW0WgmlTco9D_Tsz9OARXs1CDOHn7Xs2wZld0V2k8i54cdiX8bmjBHuVAIDQbyLgVmsjXwNnzBohIYUKtKFrLm4G5zVBJ0gz-GvIsqCW1KpDTEOrxsCPex_xvLNPboxtNMoyfQ4JnOnkD9vJEBIzXeu-gzDz7uXa0In5WXFHs59ENJYW0acjIuJaDi1OhuzBTdaU_p14vJjhJdEKrBUBCd_L3mOWdw10763IIHlQP7vQ5bqpV92kh_0NzTx6YlsGA2Dzru2sNEJ8XLIYkw3p0rYtVzUe7P0WdcdQ",
#   "results": [
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6236868,
#           "lng": 139.7336427
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.62494832989272,
#             "lng": 139.7348979298927
#           },
#           "southwest": {
#             "lat": 35.62224867010728,
#             "lng": 139.7321982701073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30d5\u30a1\u30df\u30ea\u30fc\u30de\u30fc\u30c8 \u30ac\u30fc\u30c7\u30f3\u30b7\u30c6\u30a3\u54c1\u5ddd\u5fa1\u6bbf\u5c71\u5e97",
#       "opening_hours": {
#         "open_now": false
#       },
#       "photos": [
#         {
#           "height": 3468,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/109528069076471074396\">\u4e2d\u539f\u8aa0</a>"
#           ],
#           "photo_reference": "AfLeUgMtjh_zQXYhpkopsu8FNkg2rWNFM6FoH983dYHfxWYs0PZd_MgS_NbW8316B3lOtSjTanBrzftqRMxnOhBVpYB5ywXfMf0Rfh3Me5h8Wf6IFMF8dwjlQeQ4U9Lk7ViooME-r39jml2XaBWGtHtZuoCfsNC0DowTDEj_MPAzkDKjufLK",
#           "width": 4624
#         }
#       ],
#       "place_id": "ChIJRSH77FiKGGARhB2jdDaH7g8",
#       "plus_code": {
#         "compound_code": "JPFM+FF \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJPFM+FF"
#       },
#       "rating": 2.4,
#       "reference": "ChIJRSH77FiKGGARhB2jdDaH7g8",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 17,
#       "vicinity": "\u54c1\u5ddd\u533a\u5317\u54c1\u5ddd\uff16\u4e01\u76ee\uff17\u2212\uff12\uff19"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.619232,
#           "lng": 139.730408
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.62020277989272,
#             "lng": 139.7317327298927
#           },
#           "southwest": {
#             "lat": 35.61750312010728,
#             "lng": 139.7290330701073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30d5\u30a1\u30df\u30ea\u30fc\u30de\u30fc\u30c8 \u30b2\u30fc\u30c8\u30b7\u30c6\u30a3\u5927\u5d0e\u5e97",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 2486,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/112228717848982338439\">\u91cd\u539f\u62d3\u99ac</a>"
#           ],
#           "photo_reference": "AfLeUgMkr9TCytLV09VuAsNcMHy0O70Le-agxh4fQ2fuyXbEBMKoxoS3IN85ZBj_beHYlYkLL-tN2rsMHCeXeK7OF9E0fY8dRkub3dxKLgPH5WvAK8lMrf-JdS2t4FeUTMJuRiSZcBic4D7kLGhDrvbKYp03XdGLHZ5ugVSAwaxJs1YvEgnj",
#           "width": 3729
#         }
#       ],
#       "place_id": "ChIJo3ayUWCKGGARv9SmiKqcJ5Q",
#       "plus_code": {
#         "compound_code": "JP9J+M5 \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJP9J+M5"
#       },
#       "rating": 3.1,
#       "reference": "ChIJo3ayUWCKGGARv9SmiKqcJ5Q",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 19,
#       "vicinity": "\u54c1\u5ddd\u533a\u5927\u5d0e\uff11\u4e01\u76ee\uff11\uff11\u2212\uff11"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6199605,
#           "lng": 139.7297389
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.62145782989272,
#             "lng": 139.7313414798927
#           },
#           "southwest": {
#             "lat": 35.61875817010728,
#             "lng": 139.7286418201073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30d5\u30a1\u30df\u30ea\u30fc\u30de\u30fc\u30c8 \u5927\u5d0e\u30cb\u30e5\u30fc\u30b7\u30c6\u30a3\u5e97",
#       "opening_hours": {
#         "open_now": false
#       },
#       "photos": [
#         {
#           "height": 3265,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/110807531686252733131\">Masahiko Motono</a>"
#           ],
#           "photo_reference": "AfLeUgPcEg1a5EWbcRvAE6IS804OuWgEfwaEGQII0AF620fTQAxiHHq2mvtahsHqPJdwy3BtRsQI2IVzFex9C9lNt2qrsgNIGBidbUdL1xZ3Un-S7DyudvfdpEiCatJ14J68NEt5lZUUz8jtfMpkIZ8Y3fMwynCqL6oJP_p4Anzisq2I5wNr",
#           "width": 4898
#         }
#       ],
#       "place_id": "ChIJdWYVFGCKGGARFegXbrljsXM",
#       "plus_code": {
#         "compound_code": "JP9H+XV \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJP9H+XV"
#       },
#       "rating": 3.4,
#       "reference": "ChIJdWYVFGCKGGARFegXbrljsXM",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 9,
#       "vicinity": "\u54c1\u5ddd\u533a\u5927\u5d0e\uff11\u4e01\u76ee\uff16\u2212\uff15 2F"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.621324,
#           "lng": 139.724847
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.62274772989273,
#             "lng": 139.7262523298927
#           },
#           "southwest": {
#             "lat": 35.62004807010729,
#             "lng": 139.7235526701073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30bb\u30d6\u30f3-\u30a4\u30ec\u30d6\u30f3 \u54c1\u5ddd\u5927\u5d0e\uff13\u4e01\u76ee\u5e97",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 3024,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/102124388264569947793\">Yoshinori Fukui</a>"
#           ],
#           "photo_reference": "AfLeUgMsimKopTh75yQjZlwCR4RMKWQXATGAQ5oiHkboY-B8RX4vJsBhMAYZeKtgUCMOO9Ms3gXz8gId5UoHKPW8H-JrY6uV65Fkk1wN0aTHbHwt6SVk3vHH7tA7_HR85rmeOIcWHF5LGEwKbS8nUMifdR5-_DCrNc717vAGZUPhGnJMAj-Y",
#           "width": 4032
#         }
#       ],
#       "place_id": "ChIJ31Ck_fCKGGARm9aUlJytgW0",
#       "plus_code": {
#         "compound_code": "JPCF+GW \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJPCF+GW"
#       },
#       "rating": 2.6,
#       "reference": "ChIJ31Ck_fCKGGARm9aUlJytgW0",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 16,
#       "vicinity": "\u54c1\u5ddd\u533a\u5927\u5d0e\uff13\u4e01\u76ee\uff11\u2212\uff13 \u4e45\u4fdd\u30d3\u30eb 1F"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6163502,
#           "lng": 139.7276249
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.61767327989272,
#             "lng": 139.7293942798927
#           },
#           "southwest": {
#             "lat": 35.61497362010728,
#             "lng": 139.7266946201073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30bb\u30d6\u30f3\u30a4\u30ec\u30d6\u30f3 \u5927\u5d0e\u767e\u53cd\u901a\u308a\u5e97",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 3024,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/112576703429578116383\">kei tsuyuki</a>"
#           ],
#           "photo_reference": "AfLeUgNFh4yl1-GNuVRL8t-zB5vTS9c8VHcdfOSOwEZfMORupEOIfxtz1ha4B2C2t3_YDnxqlFgNY69FzWAEr_y4CFCk81F8Vn6pQYIjBTgrNIy6Jl5s_VrYHFoJlhJjfYEccZkFJm8Y38iUv6UXX36XvHr0joaVYPKAzTRHcZURAf124Iyt",
#           "width": 4032
#         }
#       ],
#       "place_id": "ChIJh01_vvSKGGARC5XOlMHNA_8",
#       "plus_code": {
#         "compound_code": "JP8H+G2 \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJP8H+G2"
#       },
#       "rating": 2.8,
#       "reference": "ChIJh01_vvSKGGARC5XOlMHNA_8",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 17,
#       "vicinity": "\u54c1\u5ddd\u533a\u5927\u5d0e\uff12\u4e01\u76ee\uff19\u2212\uff11"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6204859,
#           "lng": 139.7269378
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.62194137989272,
#             "lng": 139.7282707798927
#           },
#           "southwest": {
#             "lat": 35.61924172010728,
#             "lng": 139.7255711201073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30d5\u30a1\u30df\u30ea\u30fc\u30de\u30fc\u30c8 \u30c8\u30ad\u30ef\u5927\u5d0e\u5e97",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 2160,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/118252634782609753961\">A Google User</a>"
#           ],
#           "photo_reference": "AfLeUgNfBl6YB1hAWSAgTuET-6YxEB0negxfAgrJmpAOqxk3XE1lmpsz0W10Oo_0SUz4oLgpQ3W4mcz2PwtB5i30N3OqUziaaPq8CSHesiv7RLSFfwLG4SVjM3-xR3etgBYta0inugTlQ6SGB4YDh3Hlzc7hvD_5eiYRO3fME52uIm5oNs4R",
#           "width": 3840
#         }
#       ],
#       "place_id": "ChIJIUydsvaKGGARu59lIFkN12M",
#       "plus_code": {
#         "compound_code": "JPCG+5Q \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJPCG+5Q"
#       },
#       "rating": 1.8,
#       "reference": "ChIJIUydsvaKGGARu59lIFkN12M",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 14,
#       "vicinity": "\u54c1\u5ddd\u533a\u5927\u5d0e\uff13\u4e01\u76ee\uff16\u2212\uff16"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6196281,
#           "lng": 139.7275456
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.62100552989273,
#             "lng": 139.7289515298927
#           },
#           "southwest": {
#             "lat": 35.61830587010729,
#             "lng": 139.7262518701073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30d5\u30a1\u30df\u30ea\u30fc\u30de\u30fc\u30c8 \u5927\u5d0e\u99c5\u897f\u53e3\u5e97",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 3000,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/110144014193510094862\">\u4e00\u662d\u7b99</a>"
#           ],
#           "photo_reference": "AfLeUgOUR-WZL2SP7V4XgSMUcAHKP9UI_mtNHojEWF_4h_DQKQvzBHAtpXiUEK_HF4oIraUl5igEvJe5ruDypANg-gY2HfEts8sbpNbbgRi5DBoEJQV37LkyXNO1PQNxRfilJzSCB2z9hKgqgWnK6GGBHpw0ihsIm4R5GeCjprtYmoYjx50Y",
#           "width": 5333
#         }
#       ],
#       "place_id": "ChIJUa6-BPSKGGARBiBQ81RtjEA",
#       "plus_code": {
#         "compound_code": "JP9H+V2 \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJP9H+V2"
#       },
#       "rating": 3.3,
#       "reference": "ChIJUa6-BPSKGGARBiBQ81RtjEA",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 12,
#       "vicinity": "\u54c1\u5ddd\u533a\u5927\u5d0e\uff13\u4e01\u76ee\uff16\u2212\uff11\uff17 \u30cb\u30e5\u30fc\u5927\u5d0e\u30d3\u30eb"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6206844,
#           "lng": 139.7287598
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.62213907989273,
#             "lng": 139.7299952798927
#           },
#           "southwest": {
#             "lat": 35.61943942010728,
#             "lng": 139.7272956201072
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30ed\u30fc\u30bd\u30f3 TOC\u5927\u5d0e\u5e97",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 1536,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/111212002279322334490\">Joshua</a>"
#           ],
#           "photo_reference": "AfLeUgOUdnCS6fY99JC7_OBxpSpeGKycqOBPou6nZI0D7MkCl3IEBvb8nxl8CJ96QDAMzkCwFU58m9zdhS5SPjkJIqTfHnEnyGhNPaRJU70bh9hEygZ3ycyya9iESSbor6livDGKUez-7fQoG5mqfQ3G-V753joasrai8uII04mXFxTl2ZzK",
#           "width": 2048
#         }
#       ],
#       "place_id": "ChIJnVCFnPaKGGAR1Nt99-woKwU",
#       "plus_code": {
#         "compound_code": "JPCH+7G \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJPCH+7G"
#       },
#       "rating": 3.9,
#       "reference": "ChIJnVCFnPaKGGAR1Nt99-woKwU",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "atm",
#         "finance",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 38,
#       "vicinity": "\u54c1\u5ddd\u533a\u5927\u5d0e\uff11\u4e01\u76ee\uff16\u2212\uff11 TOC\u30d3\u30eb 3F"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6213137,
#           "lng": 139.7281189
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.62266352989273,
#             "lng": 139.7294687298927
#           },
#           "southwest": {
#             "lat": 35.61996387010728,
#             "lng": 139.7267690701073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30bb\u30d6\u30f3-\u30a4\u30ec\u30d6\u30f3 \u5927\u5d0e\u30bb\u30f3\u30bf\u30fc\u30d3\u30eb\u5e97",
#       "opening_hours": {
#         "open_now": false
#       },
#       "photos": [
#         {
#           "height": 3888,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/108467585853328439369\">Hidetake Nagae</a>"
#           ],
#           "photo_reference": "AfLeUgP_HsHLzDt_4plrLvNavVFfNysdLG32xjUYdyzs4bBkUD71ycx2tPSm4pd3NO5tqqJtQgUwqbTX5UCwyxb7ywoOzGVyYHV1jOmZXA1r_O4Wzhk_1AkNMW1rh2yDsPycraNJoVaZ42YIm2MEqegL8JYseE8J2S2u8K3NmKCrIOwMz0nM",
#           "width": 5184
#         }
#       ],
#       "place_id": "ChIJLxQC6XmLGGARAehaMT2GBuU",
#       "plus_code": {
#         "compound_code": "JPCH+G6 \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJPCH+G6"
#       },
#       "rating": 0,
#       "reference": "ChIJLxQC6XmLGGARAehaMT2GBuU",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 0,
#       "vicinity": "\u54c1\u5ddd\u533a\u5927\u5d0e\uff11\u4e01\u76ee\uff15\u2212\uff11"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6225475,
#           "lng": 139.7290721
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.62386047989271,
#             "lng": 139.7304034298928
#           },
#           "southwest": {
#             "lat": 35.62116082010727,
#             "lng": 139.7277037701073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30d5\u30a1\u30df\u30ea\u30fc\u30de\u30fc\u30c8 \u5927\u5d0e\u99c5\u6771\u5e97",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 3024,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/102124388264569947793\">Yoshinori Fukui</a>"
#           ],
#           "photo_reference": "AfLeUgOpY_Wt0hwoys9890BP55cviryKl8LEdLu8QFV1M7oMY8XOxKWmR4c_bjcRwRnEpIVGR3LSjZ_b2Dl_xGyj8fzCFnw97lIvi0sLtrT4TtQS-SHCTYcC0Yb1oaK0vo-VJlv1s4vEwT3IgwRa_T3hNSH5ymLPDTGl2qp7OM3Nvuy48Ye2",
#           "width": 4032
#         }
#       ],
#       "place_id": "ChIJu7sZ_PaKGGAREPueNJUw-9E",
#       "plus_code": {
#         "compound_code": "JPFH+2J \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJPFH+2J"
#       },
#       "rating": 3.7,
#       "reference": "ChIJu7sZ_PaKGGAREPueNJUw-9E",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 18,
#       "vicinity": "\u54c1\u5ddd\u533a\u6771\u4e94\u53cd\u7530\uff12\u4e01\u76ee\uff11\uff16\u2212\uff11 \u30b6\u30fb\u30d1\u30fc\u30af\u30bf\u30ef\u30fc\u6771\u4eac\u30b5\u30a6\u30b9 \uff11\uff10\uff13"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.62248900000001,
#           "lng": 139.7272878
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.62383882989273,
#             "lng": 139.7286376298927
#           },
#           "southwest": {
#             "lat": 35.62113917010728,
#             "lng": 139.7259379701073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30ed\u30fc\u30bd\u30f3 \u30a2\u30fc\u30c8\u30f4\u30a3\u30ec\u30c3\u30b8\u5927\u5d0e\u5e97",
#       "opening_hours": {
#         "open_now": false
#       },
#       "photos": [
#         {
#           "height": 3268,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/110807531686252733131\">Masahiko Motono</a>"
#           ],
#           "photo_reference": "AfLeUgM9LXZVeq2r0xyIF8t4KYaiD1MaxcMFv_BFWh411Mul24w_nYVY4iiVs924b91xXFKqxQEQ9rMCvyw6t2EuMCLLVk5EOEWP6vZtkUpzwhbdMw3ExwTlnoIPSyyj0G4-OZ9MmnGffOtbMQzdff3V3GnHN_0IpepIc_b5rEDHOplcFTI2",
#           "width": 4895
#         }
#       ],
#       "place_id": "ChIJLWhAKPeKGGARhkX0uzMVfWc",
#       "plus_code": {
#         "compound_code": "JPCG+XW \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJPCG+XW"
#       },
#       "rating": 1.6,
#       "reference": "ChIJLWhAKPeKGGARhkX0uzMVfWc",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 11,
#       "vicinity": "\u54c1\u5ddd\u533a\u5927\u5d0e\uff11\u4e01\u76ee\uff12\u2212\uff12"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6189257,
#           "lng": 139.7316987
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.62070847989272,
#             "lng": 139.7329470298927
#           },
#           "southwest": {
#             "lat": 35.61800882010728,
#             "lng": 139.7302473701073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30ed\u30fc\u30bd\u30f3 \u30b2\u30fc\u30c8\u30b7\u30c6\u30a3\u5927\u5d0e\u5e97",
#       "opening_hours": {
#         "open_now": false
#       },
#       "photos": [
#         {
#           "height": 3024,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/109210591509658193880\">Nozomu Kubota</a>"
#           ],
#           "photo_reference": "AfLeUgNfrsWMCTstxCAvr-N_fjtD_y83f_aryeksUp7Azw8Y8Fgq8IEWzHgc9MqxL7fQPiTCIi4OJVeA_3fq5tTODGZ33PM0RUBIp3H_BhHpoUW8fjqbIVcFJ4kuCxiMJT6lrja8ryVTCRX2tmeup_6ai1KqTuBUaw0vSQCJnhVjy8rLJz0T",
#           "width": 4032
#         }
#       ],
#       "place_id": "ChIJP5DPcPWKGGAR81CoK5yKGGo",
#       "plus_code": {
#         "compound_code": "JP9J+HM \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJP9J+HM"
#       },
#       "rating": 3.5,
#       "reference": "ChIJP5DPcPWKGGAR81CoK5yKGGo",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 31,
#       "vicinity": "\u54c1\u5ddd\u533a\u5927\u5d0e\uff11\u4e01\u76ee\uff11\uff11\u2212\uff12 \u30a4\u30fc\u30b9\u30c8\uff11\uff26 \u30b2\u30fc\u30c8\u30b7\u30c6\u30a3\u5927\u5d0e"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6237092,
#           "lng": 139.7239824
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.62510257989272,
#             "lng": 139.7253619298928
#           },
#           "southwest": {
#             "lat": 35.62240292010728,
#             "lng": 139.7226622701073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30bb\u30d6\u30f3-\u30a4\u30ec\u30d6\u30f3 \u897f\u4e94\u53cd\u7530\uff11\u4e01\u76ee\u6771\u5e97",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 2160,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/118252634782609753961\">A Google User</a>"
#           ],
#           "photo_reference": "AfLeUgMOKOYMnKNtUObPSrbIMkfqJuauDqwM1a-TvUl9gDNLZ7k9ivnl_8Dn5VipqkYulYxKbohZnvvTm3fR6ilT5uYgdKpGzIhFCIYMJ0YOSguRUsMGhLcEcFzDdizf_PatnxgKTEeSjQC2uxezJkz43JOwwCgbLRQFMlhVim3WpfRQnuVP",
#           "width": 3840
#         }
#       ],
#       "place_id": "ChIJPb0oyI-LGGARwSujIzaYGeY",
#       "plus_code": {
#         "compound_code": "JPFF+FH \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJPFF+FH"
#       },
#       "rating": 3.6,
#       "reference": "ChIJPb0oyI-LGGARwSujIzaYGeY",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 18,
#       "vicinity": "\u54c1\u5ddd\u533a\u897f\u4e94\u53cd\u7530\uff11\u4e01\u76ee\uff11\uff14\u2212\uff12"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6170212,
#           "lng": 139.7237319
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.61840572989273,
#             "lng": 139.7250767798927
#           },
#           "southwest": {
#             "lat": 35.61570607010729,
#             "lng": 139.7223771201073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30ed\u30fc\u30bd\u30f3 \u897f\u54c1\u5ddd\u5e97",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 3915,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/110807531686252733131\">Masahiko Motono</a>"
#           ],
#           "photo_reference": "AfLeUgOXPQzIydyFwooDPVP_8jiLGOqJE3bsfBP6c3R68pboUO_egvReUlqRNFHWlJGa1tYCQ4ABzU80m4jlFeO7GcxJ5y0QDJnb128aI-YW4gI_A4965KPODlCAv1ESzK0Q79H32vDL9HXmRV_0iiVvHeYfno5KMsCEJ0NvdyzhiNIV4HHk",
#           "width": 5864
#         }
#       ],
#       "place_id": "ChIJG7FTT_KKGGARqXpaIeHRZy0",
#       "plus_code": {
#         "compound_code": "JP8F+RF \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJP8F+RF"
#       },
#       "rating": 2.8,
#       "reference": "ChIJG7FTT_KKGGARqXpaIeHRZy0",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 9,
#       "vicinity": "\u54c1\u5ddd\u533a\u897f\u54c1\u5ddd\uff13\u4e01\u76ee\uff14\u2212\uff14 \u8218\u91ce\u30cf\u30a4\u30c4"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6218827,
#           "lng": 139.7310892
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.62324852989272,
#             "lng": 139.7325252298927
#           },
#           "southwest": {
#             "lat": 35.62054887010728,
#             "lng": 139.7298255701073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30bb\u30d6\u30f3-\u30a4\u30ec\u30d6\u30f3 \u5927\u5d0e\u30d6\u30e9\u30a4\u30c8\u30b3\u30a2\u5e97",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 2000,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/113032028354122521949\">A Google User</a>"
#           ],
#           "photo_reference": "AfLeUgOnJsmRbedZIwqlS5of4NG6PIMAoDf1pDd_Wpr1grFqeqQLJsfxrupZtQMJtjBJ9PJgn28y1QW3iT2JPwouwN_tQbqse0X2Wx625_4ExSGGsqk3WfuW6ga85VNZt0Go77hycZ9xwj9pzn_zVvz_hPJcAhWj9tKA57MtnXcZfZNQ_XWn",
#           "width": 4000
#         }
#       ],
#       "place_id": "ChIJ1bp5QPaKGGAReoC4KpE1Cxc",
#       "plus_code": {
#         "compound_code": "JPCJ+QC \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJPCJ+QC"
#       },
#       "rating": 2.5,
#       "reference": "ChIJ1bp5QPaKGGAReoC4KpE1Cxc",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "atm",
#         "finance",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 28,
#       "vicinity": "\u54c1\u5ddd\u533a\u5317\u54c1\u5ddd\uff15\u4e01\u76ee\uff15\u2212\uff11\uff15"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6214631,
#           "lng": 139.7301712
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.62292092989272,
#             "lng": 139.7312947798927
#           },
#           "southwest": {
#             "lat": 35.62022127010728,
#             "lng": 139.7285951201073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30d5\u30a1\u30df\u30ea\u30fc\u30de\u30fc\u30c8 \u5927\u5d0e\u30d6\u30e9\u30a4\u30c8\u30bf\u30ef\u30fc\u5e97",
#       "opening_hours": {
#         "open_now": false
#       },
#       "photos": [
#         {
#           "height": 3977,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/110807531686252733131\">Masahiko Motono</a>"
#           ],
#           "photo_reference": "AfLeUgM7GOmA-sTDp1fxQXP6lenFfoTL9dh-w87mPRwxunybAr9i1PsSHjrkcH6W6velwJKX8OdDrtlHqhyW6D5i-2XsUuzAueENwX1rpd5theeYviBDCLdDV041v4NsgmbYoHz1ewSFmO6wkyEOrVwwozMBYktPaadplExTSSqKi_GZhG1Z",
#           "width": 5957
#         }
#       ],
#       "place_id": "ChIJ8_jWwl-KGGARIqz1437fzyU",
#       "plus_code": {
#         "compound_code": "JPCJ+H3 \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJPCJ+H3"
#       },
#       "rating": 3.1,
#       "reference": "ChIJ8_jWwl-KGGARIqz1437fzyU",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 7,
#       "vicinity": "\u54c1\u5ddd\u533a\u5317\u54c1\u5ddd\uff15\u4e01\u76ee\uff16\u2212\uff11"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6164112,
#           "lng": 139.7272889
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.61768637989272,
#             "lng": 139.7287185298927
#           },
#           "southwest": {
#             "lat": 35.61498672010728,
#             "lng": 139.7260188701073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30bb\u30d6\u30f3-\u30a4\u30ec\u30d6\u30f3 \u5927\u5d0e\u30a6\u30a8\u30b9\u30c8\u30b7\u30c6\u30a3\u30bf\u30ef\u30fc\u30ba\u5e97",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 2160,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/100677766690756971938\">A Google User</a>"
#           ],
#           "photo_reference": "AfLeUgMU5tQSmqdf7CBTuS096ApqglOPMrRYDIA56iP9sF8B8Abnypw9-Oi0zrktiZOqeK7Tf9_hlwey3zc4-nknxw7We0YFCGG_xhiyHx6m3UQ7aOtbvSnSOOlrCmuvz8BDpTWYvpw0szlXrtPPt9lfo8llP-U5oyol80TKM9znWtfMC5Dn",
#           "width": 3840
#         }
#       ],
#       "place_id": "ChIJS-WBnvSKGGARe34-LTCScLs",
#       "plus_code": {
#         "compound_code": "JP8G+HW \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJP8G+HW"
#       },
#       "rating": 2.9,
#       "reference": "ChIJS-WBnvSKGGARe34-LTCScLs",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "atm",
#         "finance",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 20,
#       "vicinity": "\u54c1\u5ddd\u533a\u5927\u5d0e\uff12\u4e01\u76ee\uff19\u2212\uff12"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6184101,
#           "lng": 139.7278839
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.61946352989273,
#             "lng": 139.7290884798927
#           },
#           "southwest": {
#             "lat": 35.61676387010728,
#             "lng": 139.7263888201072
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30d5\u30a1\u30df\u30ea\u30fc\u30de\u30fc\u30c8 \u30d5\u30a1\u30df\u30deThinkpark\u5e97",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 2938,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/111519802063070487980\">BUS1973 VW</a>"
#           ],
#           "photo_reference": "AfLeUgOWyEeUTvWdRCnWxj7E5kA5oouNTTu4ZrdeT70rTQqMaGOOYRifSpMzEtciJpjH1CsmQQUw_YU1UpI2GzkVilMHQARg6iUcZ1y02UX_xpLJTZs1oa2ASh1smlrwLNoJr0qWzo4AWtQM9CWhlGJ5qvafqc_myMJbSYZ5Xap8w1lWYT_F",
#           "width": 3918
#         }
#       ],
#       "place_id": "ChIJO_zRc_SKGGARwQjBv-S_VLY",
#       "plus_code": {
#         "compound_code": "JP9H+95 \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJP9H+95"
#       },
#       "rating": 3.9,
#       "reference": "ChIJO_zRc_SKGGARwQjBv-S_VLY",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 36,
#       "vicinity": "\u54c1\u5ddd\u533a\u5927\u5d0e\uff12\u4e01\u76ee\uff11\u2212\uff11 ThinkPark Plaza 1F"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6192789,
#           "lng": 139.7314942
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.62075187989272,
#             "lng": 139.7329037798928
#           },
#           "southwest": {
#             "lat": 35.61805222010727,
#             "lng": 139.7302041201073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30ed\u30fc\u30bd\u30f3 \u30b2\u30fc\u30c8\u30b7\u30c6\u30a3\u5927\u5d0e\u30a2\u30c8\u30ea\u30a6\u30e0\u5e97",
#       "opening_hours": {
#         "open_now": false
#       },
#       "photos": [
#         {
#           "height": 3024,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/111905439745872886914\">\u4e2d\u5c3e\u597d\u5b5d</a>"
#           ],
#           "photo_reference": "AfLeUgOBNXpNyPZeGSota547SgcYybDEPSk2lYXLxJu6GKzwfcGNGAYlsE0pYE6YKlSeRHXtUiqvEF3_5bQHWKwjduR2Fkg8MJDYS4YleHVR6A68Hb9UDxXwystQOEC9aFRIM96xfRN8DBAuW1tkXxBZbs8K4WVl0RsbO-cEZRAN7ppdgrd5",
#           "width": 4032
#         }
#       ],
#       "place_id": "ChIJIVL1fA6LGGARstWo_c98KXo",
#       "plus_code": {
#         "compound_code": "JP9J+PH \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJP9J+PH"
#       },
#       "rating": 4.4,
#       "reference": "ChIJIVL1fA6LGGARstWo_c98KXo",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 21,
#       "vicinity": "\u54c1\u5ddd\u533a\u5927\u5d0e\uff11\u4e01\u76ee\uff11\uff11\u2212\uff11"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 35.6177704,
#           "lng": 139.7324704
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 35.61916747989272,
#             "lng": 139.7338467298927
#           },
#           "southwest": {
#             "lat": 35.61646782010728,
#             "lng": 139.7311470701073
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#       "icon_background_color": "#4B96F3",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet",
#       "name": "\u30ed\u30fc\u30bd\u30f3 \u5927\u5d0e\u5e97",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 3936,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/110807531686252733131\">Masahiko Motono</a>"
#           ],
#           "photo_reference": "AfLeUgOF92e59Ea16k-t_7CxArTVZ4ig0x7Vp6pL3t3MZ-PLOmS0bnhqbm7y3K548-oxtrTJBdcQJBohsTdgrz0eB4b5MYvumVUlcO1_p-m9yiE6BgMQnrQZMzMdFP390fYVh72ude_hId1E3hIZ3aAlYs1_aj-NDAdE0JPcQzmyUVv5daZZ",
#           "width": 5896
#         }
#       ],
#       "place_id": "ChIJXzii-1-KGGARYQgDzj2kNjY",
#       "plus_code": {
#         "compound_code": "JP9J+3X \u54c1\u5ddd\u533a\u3001\u6771\u4eac\u90fd",
#         "global_code": "8Q7XJP9J+3X"
#       },
#       "rating": 3.6,
#       "reference": "ChIJXzii-1-KGGARYQgDzj2kNjY",
#       "scope": "GOOGLE",
#       "types": [
#         "convenience_store",
#         "store",
#         "food",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 9,
#       "vicinity": "\u54c1\u5ddd\u533a\u5927\u5d0e\uff11\u4e01\u76ee\uff11\uff17\u2212\uff12 \u5343\u4ee3\u7530\u5927\u5d0e\u30c9\u30eb\u30d5"
#     }
#   ],
#   "status": "OK"
# }

# %%
# APIレスポンスを取得
places = r.json()["results"]

df = pd.DataFrame(columns=['名称','住所','緯度','経度'])

# 各コンビニの位置情報を表示
for place in places:
    temp = pd.Series( [ place["name"], place["vicinity"], round(place["geometry"]["location"]["lat"], 6), round(place["geometry"]["location"]["lng"] ,6)], index=df.columns)
    df = df.append( temp,ignore_index=True )
    #df['名称'] = place["name"]
    #df['住所'] = place["vicinity"]
    #df['緯度'] = place["geometry"]["location"]["lat"]
    #df['経度'] = place["geometry"]["location"]["lng"]
    
    print("名称:", place["name"])
    print("住所:", place["vicinity"])
    print("緯度:", place["geometry"]["location"]["lat"])
    print("経度:", place["geometry"]["location"]["lng"])
    print("------------------------------")
# Out:
# 名称: ファミリーマート ガーデンシティ品川御殿山店
# 住所: 品川区北品川６丁目７−２９
# 緯度: 35.6236868
# 経度: 139.7336427
# ------------------------------
# 名称: ファミリーマート ゲートシティ大崎店
# 住所: 品川区大崎１丁目１１−１
# 緯度: 35.619232
# 経度: 139.730408
# ------------------------------
# 名称: ファミリーマート 大崎ニューシティ店
# 住所: 品川区大崎１丁目６−５ 2F
# 緯度: 35.6199605
# 経度: 139.7297389
# ------------------------------
# 名称: セブン-イレブン 品川大崎３丁目店
# 住所: 品川区大崎３丁目１−３ 久保ビル 1F
# 緯度: 35.621324
# 経度: 139.724847
# ------------------------------
# 名称: セブンイレブン 大崎百反通り店
# 住所: 品川区大崎２丁目９−１
# 緯度: 35.6163502
# 経度: 139.7276249
# ------------------------------
# 名称: ファミリーマート トキワ大崎店
# 住所: 品川区大崎３丁目６−６
# 緯度: 35.6204859
# 経度: 139.7269378
# ------------------------------
# 名称: ファミリーマート 大崎駅西口店
# 住所: 品川区大崎３丁目６−１７ ニュー大崎ビル
# 緯度: 35.6196281
# 経度: 139.7275456
# ------------------------------
# 名称: ローソン TOC大崎店
# 住所: 品川区大崎１丁目６−１ TOCビル 3F
# 緯度: 35.6206844
# 経度: 139.7287598
# ------------------------------
# 名称: セブン-イレブン 大崎センタービル店
# 住所: 品川区大崎１丁目５−１
# 緯度: 35.6213137
# 経度: 139.7281189
# ------------------------------
# 名称: ファミリーマート 大崎駅東店
# 住所: 品川区東五反田２丁目１６−１ ザ・パークタワー東京サウス １０３
# 緯度: 35.6225475
# 経度: 139.7290721
# ------------------------------
# 名称: ローソン アートヴィレッジ大崎店
# 住所: 品川区大崎１丁目２−２
# 緯度: 35.62248900000001
# 経度: 139.7272878
# ------------------------------
# 名称: ローソン ゲートシティ大崎店
# 住所: 品川区大崎１丁目１１−２ イースト１Ｆ ゲートシティ大崎
# 緯度: 35.6189257
# 経度: 139.7316987
# ------------------------------
# 名称: セブン-イレブン 西五反田１丁目東店
# 住所: 品川区西五反田１丁目１４−２
# 緯度: 35.6237092
# 経度: 139.7239824
# ------------------------------
# 名称: ローソン 西品川店
# 住所: 品川区西品川３丁目４−４ 舘野ハイツ
# 緯度: 35.6170212
# 経度: 139.7237319
# ------------------------------
# 名称: セブン-イレブン 大崎ブライトコア店
# 住所: 品川区北品川５丁目５−１５
# 緯度: 35.6218827
# 経度: 139.7310892
# ------------------------------
# 名称: ファミリーマート 大崎ブライトタワー店
# 住所: 品川区北品川５丁目６−１
# 緯度: 35.6214631
# 経度: 139.7301712
# ------------------------------
# 名称: セブン-イレブン 大崎ウエストシティタワーズ店
# 住所: 品川区大崎２丁目９−２
# 緯度: 35.6164112
# 経度: 139.7272889
# ------------------------------
# 名称: ファミリーマート ファミマThinkpark店
# 住所: 品川区大崎２丁目１−１ ThinkPark Plaza 1F
# 緯度: 35.6184101
# 経度: 139.7278839
# ------------------------------
# 名称: ローソン ゲートシティ大崎アトリウム店
# 住所: 品川区大崎１丁目１１−１
# 緯度: 35.6192789
# 経度: 139.7314942
# ------------------------------
# 名称: ローソン 大崎店
# 住所: 品川区大崎１丁目１７−２ 千代田大崎ドルフ
# 緯度: 35.6177704
# 経度: 139.7324704
# ------------------------------
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )
# C:\Users\redgr\AppData\Local\Temp\ipykernel_25032\3782010077.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append( temp,ignore_index=True )

# %%
df
# Out:
#                          名称                                住所         緯度  \
# 0    ファミリーマート ガーデンシティ品川御殿山店                     品川区北品川６丁目７−２９  35.623687
# 1        ファミリーマート ゲートシティ大崎店                      品川区大崎１丁目１１−１  35.619232
# 2        ファミリーマート 大崎ニューシティ店                    品川区大崎１丁目６−５ 2F   35.61996
# 3         セブン-イレブン 品川大崎３丁目店               品川区大崎３丁目１−３ 久保ビル 1F  35.621324
# 4           セブンイレブン 大崎百反通り店                       品川区大崎２丁目９−１   35.61635
# 5           ファミリーマート トキワ大崎店                       品川区大崎３丁目６−６  35.620486
# 6           ファミリーマート 大崎駅西口店              品川区大崎３丁目６−１７ ニュー大崎ビル  35.619628
# 7               ローソン TOC大崎店              品川区大崎１丁目６−１ TOCビル 3F  35.620684
# 8        セブン-イレブン 大崎センタービル店                       品川区大崎１丁目５−１  35.621314
# 9            ファミリーマート 大崎駅東店  品川区東五反田２丁目１６−１ ザ・パークタワー東京サウス １０３  35.622548
# 10         ローソン アートヴィレッジ大崎店                       品川区大崎１丁目２−２  35.622489
# 11           ローソン ゲートシティ大崎店      品川区大崎１丁目１１−２ イースト１Ｆ ゲートシティ大崎  35.618926
# 12       セブン-イレブン 西五反田１丁目東店                    品川区西五反田１丁目１４−２  35.623709
# 13                ローソン 西品川店                品川区西品川３丁目４−４ 舘野ハイツ  35.617021
# 14       セブン-イレブン 大崎ブライトコア店                     品川区北品川５丁目５−１５  35.621883
# 15      ファミリーマート 大崎ブライトタワー店                      品川区北品川５丁目６−１  35.621463
# 16  セブン-イレブン 大崎ウエストシティタワーズ店                       品川区大崎２丁目９−２  35.616411
# 17  ファミリーマート ファミマThinkpark店    品川区大崎２丁目１−１ ThinkPark Plaza 1F   35.61841
# 18      ローソン ゲートシティ大崎アトリウム店                      品川区大崎１丁目１１−１  35.619279
# 19                 ローソン 大崎店             品川区大崎１丁目１７−２ 千代田大崎ドルフ   35.61777
#
#             経度
# 0   139.733643
# 1   139.730408
# 2   139.729739
# 3   139.724847
# 4   139.727625
# 5   139.726938
# 6   139.727546
# 7    139.72876
# 8   139.728119
# 9   139.729072
# 10  139.727288
# 11  139.731699
# 12  139.723982
# 13  139.723732
# 14  139.731089
# 15  139.730171
# 16  139.727289
# 17  139.727884
# 18  139.731494
# 19   139.73247

# %%
from geopy.distance import geodesic

# %%
home   = (lat, lng)
home_d = (df["緯度"][1],df["経度"][1])

# %%
dis = geodesic(home, home_d)

# %%
dis
# Out:
# Distance(0.13328311172027021)

# %%
#関数化
def Map_distance(x):
    home_dis = (x["緯度"], x["経度"])
    dis = geodesic(home, home_dis)
    return dis

# %%
df['距離'] = df.apply(Map_distance, axis=1)

# %%
df
# Out:
#                          名称                                住所         緯度  \
# 0    ファミリーマート ガーデンシティ品川御殿山店                     品川区北品川６丁目７−２９  35.623687
# 1        ファミリーマート ゲートシティ大崎店                      品川区大崎１丁目１１−１  35.619232
# 2        ファミリーマート 大崎ニューシティ店                    品川区大崎１丁目６−５ 2F   35.61996
# 3         セブン-イレブン 品川大崎３丁目店               品川区大崎３丁目１−３ 久保ビル 1F  35.621324
# 4           セブンイレブン 大崎百反通り店                       品川区大崎２丁目９−１   35.61635
# 5           ファミリーマート トキワ大崎店                       品川区大崎３丁目６−６  35.620486
# 6           ファミリーマート 大崎駅西口店              品川区大崎３丁目６−１７ ニュー大崎ビル  35.619628
# 7               ローソン TOC大崎店              品川区大崎１丁目６−１ TOCビル 3F  35.620684
# 8        セブン-イレブン 大崎センタービル店                       品川区大崎１丁目５−１  35.621314
# 9            ファミリーマート 大崎駅東店  品川区東五反田２丁目１６−１ ザ・パークタワー東京サウス １０３  35.622548
# 10         ローソン アートヴィレッジ大崎店                       品川区大崎１丁目２−２  35.622489
# 11           ローソン ゲートシティ大崎店      品川区大崎１丁目１１−２ イースト１Ｆ ゲートシティ大崎  35.618926
# 12       セブン-イレブン 西五反田１丁目東店                    品川区西五反田１丁目１４−２  35.623709
# 13                ローソン 西品川店                品川区西品川３丁目４−４ 舘野ハイツ  35.617021
# 14       セブン-イレブン 大崎ブライトコア店                     品川区北品川５丁目５−１５  35.621883
# 15      ファミリーマート 大崎ブライトタワー店                      品川区北品川５丁目６−１  35.621463
# 16  セブン-イレブン 大崎ウエストシティタワーズ店                       品川区大崎２丁目９−２  35.616411
# 17  ファミリーマート ファミマThinkpark店    品川区大崎２丁目１−１ ThinkPark Plaza 1F   35.61841
# 18      ローソン ゲートシティ大崎アトリウム店                      品川区大崎１丁目１１−１  35.619279
# 19                 ローソン 大崎店             品川区大崎１丁目１７−２ 千代田大崎ドルフ   35.61777
#
#             経度                      距離
# 0   139.733643   0.5452487470690593 km
# 1   139.730408  0.13328311172027021 km
# 2   139.729739  0.03291727293633558 km
# 3   139.724847  0.43784403224434537 km
# 4   139.727625  0.45348180032386354 km
# 5   139.726938  0.23164244876674386 km
# 6   139.727546  0.18305663751440615 km
# 7    139.72876  0.08676796372610578 km
# 8   139.728119   0.1772704678265207 km
# 9   139.729072   0.2681785235228537 km
# 10  139.727288  0.32561108563556573 km
# 11  139.731699  0.24407919754639243 km
# 12  139.723982   0.6342009160047826 km
# 13  139.723732   0.6246276840140623 km
# 14  139.731089  0.24209815405523075 km
# 15  139.730171   0.1590082574661778 km
# 16  139.727289   0.4593910562217194 km
# 17  139.727884    0.240403378956671 km
# 18  139.731494   0.2080156769176744 km
# 19   139.73247  0.37961845992141513 km
